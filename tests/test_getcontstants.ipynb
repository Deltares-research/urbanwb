# %%
import numpy as np
import numpy.testing as npt
import pandas as pd
import pytest

import urbanwb
from urbanwb.getconstants import getconstants
 ##Still the question lies, if the getconstants class has to be made..

path = urbanwb.urbanwbdir / ".." / "input"
InputData = pd.read_csv(path / "integration_test" / "input_csv.csv")
date = InputData["date"]
P_atm = InputData["P_atm"]
E_pot_OW = InputData["E_pot_OW"]
iters = np.shape(date)[0]

# %%
# Out:
# 0        0.000
# 1        0.000
# 2        0.000
# 3        0.000
# 4        0.000
#          ...
# 43820    1.016
# 43821    4.318
# 43822    0.000
# 43823    0.000
# 43824    0.000
# Name: P_atm, Length: 43825, dtype: float64
